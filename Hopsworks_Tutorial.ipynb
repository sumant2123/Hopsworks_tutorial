# %%
import pandas as pd
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar
import requests
import hopsworks
import os
# %load_ext dotenv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [6], in <cell line: 4>()
#       2 from pandas.tseries.holiday import USFederalHolidayCalendar as calendar
#       3 import requests
# ----> 4 import hopsworks
#       5 import os
#       6 get_ipython().run_line_magic('load_ext', 'dotenv')
#
# ModuleNotFoundError: No module named 'hopsworks'

# %%
pip install hopsworks
# Out:
# ...
#   Using cached hopsworks-3.0.5-py3-none-any.whl
# ...
#   Using cached hsfs-3.0.5-py3-none-any.whl
# ...
#   Using cached furl-2.1.3-py2.py3-none-any.whl (20 kB)
# ...
#   Using cached hsml-3.0.3-py3-none-any.whl
# ...
#   Using cached pyjks-20.0.0-py2.py3-none-any.whl (45 kB)
# ...
#   Using cached pyhumps-1.6.1-py3-none-any.whl (5.0 kB)
# ...
#   Using cached PyMySQL-1.0.3-py3-none-any.whl (43 kB)
# ...
#   Using cached great_expectations-0.14.12-py3-none-any.whl (4.9 MB)
# ...
#   Using cached avro-1.10.2-py3-none-any.whl
# ...
#   Using cached PyHopsHive-0.6.4.1.dev0-py3-none-any.whl
# ...
#   Using cached pyarrow-11.0.0-cp39-cp39-win_amd64.whl (20.6 MB)
# ...
#   Using cached confluent_kafka-1.8.2-cp39-cp39-win_amd64.whl (2.6 MB)
# ...
#   Using cached fastavro-1.4.11-cp39-cp39-win_amd64.whl (416 kB)
# ...
#   Using cached jsonpatch-1.32-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached ruamel.yaml-0.17.17-py3-none-any.whl (109 kB)
# ...
#   Using cached altair-4.2.2-py3-none-any.whl (813 kB)
# ...
#   Using cached tzlocal-4.3-py3-none-any.whl (20 kB)
# ...

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# absl-py                       1.2.0
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# alabaster                     0.7.12
# alembic                       1.8.1
# anaconda-client               1.9.0
# anaconda-navigator            2.1.4
# anaconda-project              0.10.2
# ansi2html                     1.8.0
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.2
# astroid                       2.6.6
# astropy                       5.0.4
# asttokens                     2.0.5
# astunparse                    1.6.3
# async-timeout                 4.0.1
# atomicwrites                  1.4.0
# attrs                         21.4.0
# Automat                       20.2.0
# autopage                      0.5.1
# ...

# %%
# !jupyter --version
# Out:
# Selected Jupyter core packages...
# IPython          : 8.2.0
# ipykernel        : 6.9.1
# ipywidgets       : 7.6.5
# jupyter_client   : 6.1.12
# jupyter_core     : 4.9.2
# jupyter_server   : 1.13.5
# jupyterlab       : 3.3.2
# nbclient         : 0.5.13
# nbconvert        : 6.4.4
# nbformat         : 5.3.0
# notebook         : 6.4.8
# qtconsole        : 5.3.0
# traitlets        : 5.1.1

# %%
# !python --version
# Out:
# Python 3.9.12
